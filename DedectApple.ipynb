# %% [markdown]
# # Dedect Apple with yolov5

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
# %matplotlib inline

# %%
# Reading the image 
image = cv2.imread("/users/melih/apple.jpg")
# Print image pixel size and color channels
print(image.shape)
# Out:
# (612, 612, 3)

# %%
# Convert image from BGR to RGB
image_rgb = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
plt.imshow(image_rgb);

# %%
# Converting image to gray scale 
gray_image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)

# Plotting the grayscale image
cv2.imshow("Grayscale Image", gray_image)

# The window will stay open indefinitely until any key is pressed.
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
fig, ax = plt.subplots(1, 3, figsize=(15,15))

r = image.copy()
# set blue and green channels to 0
r[:, :, 1] = 0
r[:, :, 2] = 0

g = image.copy()
# set blue and red channels to 0
g[:, :, 0] = 0
g[:, :, 2] = 0

b = image.copy()
# set red and green channels to 0
b[:, :, 0] = 0
b[:, :, 1] = 0

ax[0].imshow(r)
ax[1].imshow(g)
ax[2].imshow(b);

# %%
#calculate the edges using Canny edge algorithm
edges = cv2.Canny(image,100,200) 
#plot the edges
plt.imshow(edges);

# %%
# Saves image too your current directory
cv2.imwrite('edges.jpg',edges)
# Out:
# True

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-173-g5733342 Python-3.9.13 torch-2.0.1 CPU
# Setup complete ✅ (8 CPUs, 16.0 GB RAM, 144.0/228.3 GB disk)

# %%
# !python detect.py --weights yolov5s.pt --img 640 --conf 0.25 --source 0
# Out:
# detect: weights=['yolov5s.pt'], source=0, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-173-g5733342 Python-3.9.13 torch-2.0.1 CPU
#
# Fusing layers...
# [W NNPACK.cpp:64] Could not initialize NNPACK! Reason: Unsupported hardware.
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# 1/1: 0...  Success (inf frames 1280x720 at 30.00 FPS)
#
# 0: 384x640 (no detections), 278.8ms
# 0: 384x640 1 person, 1 donut, 185.3ms
# 0: 384x640 1 person, 1 donut, 1 cake, 222.9ms
# 0: 384x640 1 person, 2 donuts, 215.1ms
# 0: 384x640 1 person, 1 banana, 1 pizza, 2 donuts, 1 cake, 213.8ms
# ...
